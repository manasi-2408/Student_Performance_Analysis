# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
data = pd.read_csv(r'../data/StudentsPerformance.csv')

# %%
data
# Out:
#      Gender     Race Parental_Level_of_Education         Lunch  \
# 0    Female  Group B            Bachelors Degree      Standard
# 1    Female  Group C                     College      Standard
# 2    Female  Group B              Masters Degree      Standard
# 3      Male  Group A            Associate Degree  Free/Reduced
# 4      Male  Group C                     College      Standard
# ..      ...      ...                         ...           ...
# 995  Female  Group E              Masters Degree      Standard
# 996    Male  Group C                 High School  Free/Reduced
# 997  Female  Group C                 High School  Free/Reduced
# 998  Female  Group D                     College      Standard
# 999  Female  Group D                     College  Free/Reduced
#
#     Test_Preparation  Math_Score  Reading_Score  Writing_Score
# 0      Not Completed          72             72             74
# 1          Completed          69             90             88
# 2      Not Completed          90             95             93
# 3      Not Completed          47             57             44
# 4      Not Completed          76             78             75
# ..               ...         ...            ...            ...
# 995        Completed          88             99             95
# 996    Not Completed          62             55             55
# 997        Completed          59             71             65
# 998        Completed          68             78             77
# 999    Not Completed          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## Extracting basic information from the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       1000 non-null   object
#  1   Race                         1000 non-null   object
#  2   Parental_Level_of_Education  1000 non-null   object
#  3   Lunch                        1000 non-null   object
#  4   Test_Preparation             1000 non-null   object
#  5   Math_Score                   1000 non-null   int64
#  6   Reading_Score                1000 non-null   int64
#  7   Writing_Score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.size
# Out:
# 8000

# %%
data.columns
# Out:
# Index(['Gender', 'Race', 'Parental_Level_of_Education', 'Lunch',
#        'Test_Preparation', 'Math_Score', 'Reading_Score', 'Writing_Score'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Gender                         0
# Race                           0
# Parental_Level_of_Education    0
# Lunch                          0
# Test_Preparation               0
# Math_Score                     0
# Reading_Score                  0
# Writing_Score                  0
# dtype: int64

# %%
data.describe(include='all')
# Out:
#         Gender     Race Parental_Level_of_Education     Lunch  \
# count     1000     1000                        1000      1000
# unique       2        5                           5         2
# top     Female  Group C                 High School  Standard
# freq       518      319                         375       645
# mean       NaN      NaN                         NaN       NaN
# std        NaN      NaN                         NaN       NaN
# min        NaN      NaN                         NaN       NaN
# 25%        NaN      NaN                         NaN       NaN
# 50%        NaN      NaN                         NaN       NaN
# 75%        NaN      NaN                         NaN       NaN
# max        NaN      NaN                         NaN       NaN
#
#        Test_Preparation  Math_Score  Reading_Score  Writing_Score
# count              1000  1000.00000    1000.000000    1000.000000
# unique                2         NaN            NaN            NaN
# top       Not Completed         NaN            NaN            NaN
# freq                642         NaN            NaN            NaN
# mean                NaN    66.08900      69.169000      68.054000
# std                 NaN    15.16308      14.600192      15.195657
# min                 NaN     0.00000      17.000000      10.000000
# 25%                 NaN    57.00000      59.000000      57.750000
# 50%                 NaN    66.00000      70.000000      69.000000
# 75%                 NaN    77.00000      79.000000      79.000000
# max                 NaN   100.00000     100.000000     100.000000

# %%
data.dtypes
# Out:
# Gender                         object
# Race                           object
# Parental_Level_of_Education    object
# Lunch                          object
# Test_Preparation               object
# Math_Score                      int64
# Reading_Score                   int64
# Writing_Score                   int64
# dtype: object

# %% [markdown]
# ## Renaming every column

# %%
data.rename(columns={
    'gender':'Gender',
    'race/ethnicity':'Race',
    'parental level of education':'Parental_Level_of_Education',
    'lunch':'Lunch',
    'test preparation course':'Test_Preparation',
    'math score':'Math_Score',
    'reading score':'Reading_Score',
    'writing score':'Writing_Score'
}, inplace=True)

# %%
data.head()
# Out:
#    Gender     Race Parental_Level_of_Education         Lunch Test_Preparation  \
# 0  Female  Group B            Bachelors Degree      Standard    Not Completed
# 1  Female  Group C                     College      Standard        Completed
# 2  Female  Group B              Masters Degree      Standard    Not Completed
# 3    Male  Group A            Associate Degree  Free/Reduced    Not Completed
# 4    Male  Group C                     College      Standard    Not Completed
#
#    Math_Score  Reading_Score  Writing_Score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## Working with Gender column

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['Gender'] = data['Gender'].str.title()

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data.head()
# Out:
#    Gender     Race Parental_Level_of_Education         Lunch Test_Preparation  \
# 0  Female  Group B            Bachelors Degree      Standard    Not Completed
# 1  Female  Group C                     College      Standard        Completed
# 2  Female  Group B              Masters Degree      Standard    Not Completed
# 3    Male  Group A            Associate Degree  Free/Reduced    Not Completed
# 4    Male  Group C                     College      Standard    Not Completed
#
#    Math_Score  Reading_Score  Writing_Score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## Working with Race column

# %%
data['Race'].unique()
# Out:
# array(['Group B', 'Group C', 'Group A', 'Group D', 'Group E'],
#       dtype=object)

# %%
data['Race'] = data['Race'].str.title()

# %%
data['Race'].unique()
# Out:
# array(['Group B', 'Group C', 'Group A', 'Group D', 'Group E'],
#       dtype=object)

# %% [markdown]
# Working with Parental_Level_of_Education column

# %%
data['Parental_Level_of_Education'].unique()
# Out:
# array(['Bachelors Degree', 'College', 'Masters Degree',
#        'Associate Degree', 'High School'], dtype=object)

# %%
data["Parental_Level_of_Education"] = (
    data["Parental_Level_of_Education"].replace({
        "some college": "college",
        "bachelor's degree": "bachelors degree",
        "master's degree": "masters degree",
        "associate's degree": "associate degree",
        "some high school": "high school"
    }))

# %%
data['Parental_Level_of_Education'] = data['Parental_Level_of_Education'].str.title()

# %%
data.head()
# Out:
#    Gender     Race Parental_Level_of_Education         Lunch Test_Preparation  \
# 0  Female  Group B            Bachelors Degree      Standard    Not Completed
# 1  Female  Group C                     College      Standard        Completed
# 2  Female  Group B              Masters Degree      Standard    Not Completed
# 3    Male  Group A            Associate Degree  Free/Reduced    Not Completed
# 4    Male  Group C                     College      Standard    Not Completed
#
#    Math_Score  Reading_Score  Writing_Score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## Working with Lunch column

# %%
data['Lunch'].unique()
# Out:
# array(['Standard', 'Free/Reduced'], dtype=object)

# %%
data['Lunch'] = data['Lunch'].str.title()

# %%
data.head()
# Out:
#    Gender     Race Parental_Level_of_Education         Lunch Test_Preparation  \
# 0  Female  Group B            Bachelors Degree      Standard    Not Completed
# 1  Female  Group C                     College      Standard        Completed
# 2  Female  Group B              Masters Degree      Standard    Not Completed
# 3    Male  Group A            Associate Degree  Free/Reduced    Not Completed
# 4    Male  Group C                     College      Standard    Not Completed
#
#    Math_Score  Reading_Score  Writing_Score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## Working with Test_Preparation column

# %%
data['Test_Preparation'].unique()
# Out:
# array(['Not Completed', 'Completed'], dtype=object)

# %%
data['Test_Preparation'] = data['Test_Preparation'].str.title()

# %%
data['Test_Preparation'] = data['Test_Preparation'].fillna('Not Completed')

# %% [markdown]
# ## Seeing the final data

# %%
data.head()
# Out:
#    Gender     Race Parental_Level_of_Education         Lunch Test_Preparation  \
# 0  Female  Group B            Bachelors Degree      Standard    Not Completed
# 1  Female  Group C                     College      Standard        Completed
# 2  Female  Group B              Masters Degree      Standard    Not Completed
# 3    Male  Group A            Associate Degree  Free/Reduced    Not Completed
# 4    Male  Group C                     College      Standard    Not Completed
#
#    Math_Score  Reading_Score  Writing_Score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ## Saving the file

# %%
data.to_csv(r'StudentsPerformance.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.to_csv(r'StudentsPerformance.csv', index=False)
#
# NameError: name 'data' is not defined
